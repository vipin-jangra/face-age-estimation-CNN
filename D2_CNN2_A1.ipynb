# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin-jangra/face-age-estimation-CNN/blob/main/D2_CNN2_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import re
import cv2
import keras
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.applications import ResNet101
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img, img_to_array
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from keras.applications.resnet50 import preprocess_input

# %%
def preprocess_image(image_path):
    # Read grayscale image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    # Resize image to (224, 224)
    image = cv2.resize(image, (224, 224))
    # Convert grayscale to RGB by stacking the single channel
    image_rgb = np.stack((image,) * 3, axis=-1)
    # Preprocess image for ResNet50 model
    image_rgb = preprocess_input(image_rgb)
    return image_rgb

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define age group conversion
def age_to_range(age):
    return age // 3 # Convert ages to 3-year interval indices

# %%
def preprocess_labels(labels, num_classes):
    # One-hot encode labels
    labels = to_categorical(labels, num_classes=num_classes)
    return labels

# %%
# Load and preprocess the dataset
image_dir = '/content/drive/MyDrive/Dataset/Dataset2/FGNET/images'
images=[]
image_paths = []
age_labels = []
age_groups = []
target_size = (224, 224)

for filename in os.listdir(image_dir):
  if filename.endswith(".JPG"):
    match = re.search(r'A(\d+)', filename)
    age_str = match.group(1)
    age = int(age_str)
    range_index = age_to_range(age)
    age_labels.append(range_index)

    image_path = os.path.join(image_dir, filename)
    image = preprocess_image(image_path)
    images.append(image)
    image_paths.append(image_path)

images = np.array(images)
age_groups = age_labels
age_labels = preprocess_labels(age_labels, np.max(age_groups)+1)

# %%
# Print shapes
print(f"Images shape: {images.shape}")
print(f"Labels shape: {age_labels.shape}")
# Out:
# Images shape: (1002, 224, 224, 3)
# Labels shape: (1002, 24)

# %%
def age_group_to_interval(group_index, interval=5):
    start = group_index * interval
    end = (group_index + 1) * interval - 1
    return f"{start}-{end}"

# %%
import pandas as pd
df = pd.DataFrame()
age_intervals = [age_group_to_interval(age) for age in age_groups]
df['images_path'],df['age'] = image_paths,age_intervals
df.head(10)
# Out:
#                                          images_path    age
# 0  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  10-14
# 1  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...    0-4
# 2  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  15-19
# 3  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...    5-9
# 4  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  70-74
# 5  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  30-34
# 6  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  50-54
# 7  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  85-89
# 8  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  95-99
# 9  /content/drive/MyDrive/Dataset/Dataset2/FGNET/...  50-54

# %%
plt.figure(figsize=(20,20))
samples = df.iloc[0:16]

for index,sample,age in samples.itertuples():
  plt.subplot(4,4,index+1)
  img = load_img(sample)
  img = np.array(img)
  plt.axis('off')
  plt.title(f'Age:{age}')
  plt.imshow(img)

# %%
#age distribution
sns.displot(data=age_intervals,kde=True)

# %%
train_images, test_images, train_age_groups, test_age_groups = train_test_split(images, age_labels, test_size=0.2, random_state=42)

# %%
# Load the pre-trained ResNet50 model
base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(132, activation='relu')(x)
predictions = Dense(np.max(age_groups) + 1, activation='softmax')(x)

# Create the complete model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 8s 0us/step

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(
   '/content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5',  # Filepath to save the best model
    monitor='val_accuracy',  # Metric to monitor
    verbose=1,
    save_best_only=True,  # Only save the best model
    mode='max'  # Mode to determine best (maximizing validation accuracy)
)

# %%
model.fit(train_images, train_age_groups, validation_split=0.2, epochs=60, batch_size=32, callbacks=[early_stopping,model_checkpoint], shuffle=False)
# Out:
# Epoch 1/60
# 20/20 [==============================] - ETA: 0s - loss: 2.9279 - accuracy: 0.1266
# Epoch 1: val_accuracy improved from -inf to 0.02484, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 20/20 [==============================] - 79s 605ms/step - loss: 2.9279 - accuracy: 0.1266 - val_loss: 59308140.0000 - val_accuracy: 0.0248
# Epoch 2/60
# 20/20 [==============================] - ETA: 0s - loss: 2.4942 - accuracy: 0.1906
# Epoch 2: val_accuracy improved from 0.02484 to 0.08075, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 402ms/step - loss: 2.4942 - accuracy: 0.1906 - val_loss: 2111509.2500 - val_accuracy: 0.0807
# Epoch 3/60
# 20/20 [==============================] - ETA: 0s - loss: 2.2834 - accuracy: 0.2297
# Epoch 3: val_accuracy improved from 0.08075 to 0.11801, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 425ms/step - loss: 2.2834 - accuracy: 0.2297 - val_loss: 4046.5972 - val_accuracy: 0.1180
# Epoch 4/60
# 20/20 [==============================] - ETA: 0s - loss: 2.1575 - accuracy: 0.2797
# Epoch 4: val_accuracy did not improve from 0.11801
# 20/20 [==============================] - 5s 265ms/step - loss: 2.1575 - accuracy: 0.2797 - val_loss: 103.3916 - val_accuracy: 0.1118
# Epoch 5/60
# 20/20 [==============================] - ETA: 0s - loss: 1.9338 - accuracy: 0.3313
# Epoch 5: val_accuracy did not improve from 0.11801
# 20/20 [==============================] - 5s 256ms/step - loss: 1.9338 - accuracy: 0.3313 - val_loss: 300.8914 - val_accuracy: 0.1180
# Epoch 6/60
# 20/20 [==============================] - ETA: 0s - loss: 1.7412 - accuracy: 0.3969
# Epoch 6: val_accuracy improved from 0.11801 to 0.13043, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 395ms/step - loss: 1.7412 - accuracy: 0.3969 - val_loss: 122.9518 - val_accuracy: 0.1304
# Epoch 7/60
# 20/20 [==============================] - ETA: 0s - loss: 1.5380 - accuracy: 0.4719
# Epoch 7: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 270ms/step - loss: 1.5380 - accuracy: 0.4719 - val_loss: 6.4163 - val_accuracy: 0.1242
# Epoch 8/60
# 20/20 [==============================] - ETA: 0s - loss: 1.3455 - accuracy: 0.5375
# Epoch 8: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 258ms/step - loss: 1.3455 - accuracy: 0.5375 - val_loss: 7.1570 - val_accuracy: 0.0994
# Epoch 9/60
# 20/20 [==============================] - ETA: 0s - loss: 1.3155 - accuracy: 0.5453
# Epoch 9: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 258ms/step - loss: 1.3155 - accuracy: 0.5453 - val_loss: 9.5171 - val_accuracy: 0.0807
# Epoch 10/60
# 20/20 [==============================] - ETA: 0s - loss: 1.1646 - accuracy: 0.6094
# Epoch 10: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 259ms/step - loss: 1.1646 - accuracy: 0.6094 - val_loss: 17.3329 - val_accuracy: 0.0683
# Epoch 11/60
# 20/20 [==============================] - ETA: 0s - loss: 0.9226 - accuracy: 0.6797
# Epoch 11: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 258ms/step - loss: 0.9226 - accuracy: 0.6797 - val_loss: 6.9962 - val_accuracy: 0.1118
# Epoch 12/60
# 20/20 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.8000
# Epoch 12: val_accuracy did not improve from 0.13043
# 20/20 [==============================] - 5s 258ms/step - loss: 0.6856 - accuracy: 0.8000 - val_loss: 20.7435 - val_accuracy: 0.0683
# Epoch 13/60
# 20/20 [==============================] - ETA: 0s - loss: 0.4869 - accuracy: 0.8547
# Epoch 13: val_accuracy improved from 0.13043 to 0.15528, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4869 - accuracy: 0.8547 - val_loss: 11.0600 - val_accuracy: 0.1553
# Epoch 14/60
# 20/20 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.9000
# Epoch 14: val_accuracy did not improve from 0.15528
# 20/20 [==============================] - 5s 260ms/step - loss: 0.3851 - accuracy: 0.9000 - val_loss: 12.8910 - val_accuracy: 0.0745
# Epoch 15/60
# 20/20 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.9016
# Epoch 15: val_accuracy did not improve from 0.15528
# 20/20 [==============================] - 5s 268ms/step - loss: 0.2884 - accuracy: 0.9016 - val_loss: 6.1970 - val_accuracy: 0.1491
# Epoch 16/60
# 20/20 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9484
# Epoch 16: val_accuracy improved from 0.15528 to 0.18634, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 402ms/step - loss: 0.1905 - accuracy: 0.9484 - val_loss: 5.2234 - val_accuracy: 0.1863
# Epoch 17/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9812
# Epoch 17: val_accuracy improved from 0.18634 to 0.24845, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0858 - accuracy: 0.9812 - val_loss: 6.1226 - val_accuracy: 0.2484
# Epoch 18/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9906
# Epoch 18: val_accuracy did not improve from 0.24845
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0547 - accuracy: 0.9906 - val_loss: 6.2062 - val_accuracy: 0.1988
# Epoch 19/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9969
# Epoch 19: val_accuracy did not improve from 0.24845
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0212 - accuracy: 0.9969 - val_loss: 5.9342 - val_accuracy: 0.2112
# Epoch 20/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 20: val_accuracy improved from 0.24845 to 0.27329, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 402ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 4.8641 - val_accuracy: 0.2733
# Epoch 21/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 21: val_accuracy improved from 0.27329 to 0.29814, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.6157 - val_accuracy: 0.2981
# Epoch 22/60
# 20/20 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 22: val_accuracy improved from 0.29814 to 0.31056, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.5272 - val_accuracy: 0.3106
# Epoch 23/60
# 20/20 [==============================] - ETA: 0s - loss: 8.3562e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.31056
# 20/20 [==============================] - 5s 269ms/step - loss: 8.3562e-04 - accuracy: 1.0000 - val_loss: 4.4776 - val_accuracy: 0.3106
# Epoch 24/60
# 20/20 [==============================] - ETA: 0s - loss: 6.8177e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.31056 to 0.32919, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 404ms/step - loss: 6.8177e-04 - accuracy: 1.0000 - val_loss: 4.4435 - val_accuracy: 0.3292
# Epoch 25/60
# 20/20 [==============================] - ETA: 0s - loss: 5.7685e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy improved from 0.32919 to 0.34161, saving model to /content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5
# 20/20 [==============================] - 8s 405ms/step - loss: 5.7685e-04 - accuracy: 1.0000 - val_loss: 4.4217 - val_accuracy: 0.3416
# Epoch 26/60
# 20/20 [==============================] - ETA: 0s - loss: 4.9881e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 268ms/step - loss: 4.9881e-04 - accuracy: 1.0000 - val_loss: 4.4127 - val_accuracy: 0.3354
# Epoch 27/60
# 20/20 [==============================] - ETA: 0s - loss: 4.3768e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 269ms/step - loss: 4.3768e-04 - accuracy: 1.0000 - val_loss: 4.4117 - val_accuracy: 0.3292
# Epoch 28/60
# 20/20 [==============================] - ETA: 0s - loss: 3.8852e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 3.8852e-04 - accuracy: 1.0000 - val_loss: 4.4160 - val_accuracy: 0.3292
# Epoch 29/60
# 20/20 [==============================] - ETA: 0s - loss: 3.4805e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 258ms/step - loss: 3.4805e-04 - accuracy: 1.0000 - val_loss: 4.4256 - val_accuracy: 0.3292
# Epoch 30/60
# 20/20 [==============================] - ETA: 0s - loss: 3.1401e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 3.1401e-04 - accuracy: 1.0000 - val_loss: 4.4384 - val_accuracy: 0.3230
# Epoch 31/60
# 20/20 [==============================] - ETA: 0s - loss: 2.8511e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 258ms/step - loss: 2.8511e-04 - accuracy: 1.0000 - val_loss: 4.4528 - val_accuracy: 0.3106
# Epoch 32/60
# 20/20 [==============================] - ETA: 0s - loss: 2.6020e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 2.6020e-04 - accuracy: 1.0000 - val_loss: 4.4692 - val_accuracy: 0.3168
# Epoch 33/60
# 20/20 [==============================] - ETA: 0s - loss: 2.3857e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 258ms/step - loss: 2.3857e-04 - accuracy: 1.0000 - val_loss: 4.4866 - val_accuracy: 0.3168
# Epoch 34/60
# 20/20 [==============================] - ETA: 0s - loss: 2.1968e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 258ms/step - loss: 2.1968e-04 - accuracy: 1.0000 - val_loss: 4.5049 - val_accuracy: 0.3168
# Epoch 35/60
# 20/20 [==============================] - ETA: 0s - loss: 2.0299e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 2.0299e-04 - accuracy: 1.0000 - val_loss: 4.5241 - val_accuracy: 0.3168
# Epoch 36/60
# 20/20 [==============================] - ETA: 0s - loss: 1.8815e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 1.8815e-04 - accuracy: 1.0000 - val_loss: 4.5448 - val_accuracy: 0.3168
# Epoch 37/60
# 20/20 [==============================] - ETA: 0s - loss: 1.7483e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 256ms/step - loss: 1.7483e-04 - accuracy: 1.0000 - val_loss: 4.5643 - val_accuracy: 0.3168
# Epoch 38/60
# 20/20 [==============================] - ETA: 0s - loss: 1.6289e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 256ms/step - loss: 1.6289e-04 - accuracy: 1.0000 - val_loss: 4.5840 - val_accuracy: 0.3168
# Epoch 39/60
# 20/20 [==============================] - ETA: 0s - loss: 1.5208e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 1.5208e-04 - accuracy: 1.0000 - val_loss: 4.6039 - val_accuracy: 0.3168
# Epoch 40/60
# 20/20 [==============================] - ETA: 0s - loss: 1.4234e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 256ms/step - loss: 1.4234e-04 - accuracy: 1.0000 - val_loss: 4.6240 - val_accuracy: 0.3168
# Epoch 41/60
# 20/20 [==============================] - ETA: 0s - loss: 1.3351e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 257ms/step - loss: 1.3351e-04 - accuracy: 1.0000 - val_loss: 4.6438 - val_accuracy: 0.3168
# Epoch 42/60
# 20/20 [==============================] - ETA: 0s - loss: 1.2544e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.34161
# 20/20 [==============================] - 5s 274ms/step - loss: 1.2544e-04 - accuracy: 1.0000 - val_loss: 4.6629 - val_accuracy: 0.3168

# %%
# Load the best model
model.load_weights('/content/drive/MyDrive/Dataset/Dataset2/model-weights/D2_CNN2_A1.h5')

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_age_groups)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 7/7 [==============================] - 1s 172ms/step - loss: 5.0034 - accuracy: 0.2239
# Test Accuracy: 22.39%

# %%
predictions = model.predict(test_images)

# Convert predictions to class labels if needed
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_age_groups, axis=1)
# Out:
# 7/7 [==============================] - 2s 75ms/step

# %%
# Example metrics calculation
from sklearn.metrics import classification_report

print(classification_report(true_classes, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79        12
#            1       0.48      0.42      0.45        26
#            2       0.32      0.46      0.38        24
#            3       0.11      0.11      0.11        19
#            4       0.17      0.33      0.22        15
#            5       0.22      0.14      0.17        28
#            6       0.00      0.00      0.00        20
#            7       0.00      0.00      0.00        16
#            8       0.00      0.00      0.00         9
#            9       0.00      0.00      0.00         6
#           10       0.00      0.00      0.00         2
#           11       0.00      0.00      0.00         2
#           12       0.00      0.00      0.00         2
#           13       0.20      0.12      0.15         8
#           14       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         4
#           16       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00         1
#           18       0.00      0.00      0.00         1
#           20       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         1
#           23       0.00      0.00      0.00         1
#
#     accuracy                           0.22       201
#    macro avg       0.10      0.11      0.10       201
# weighted avg       0.20      0.22      0.21       201
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculate classification metrics
accuracy = accuracy_score(true_classes, predicted_classes)
precision = precision_score(true_classes, predicted_classes, average='weighted')
recall = recall_score(true_classes, predicted_classes, average='weighted')
f1 = f1_score(true_classes, predicted_classes, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Accuracy: 0.22
# Precision: 0.20
# Recall: 0.22
# F1-score: 0.21
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculate accuracy for each class
class_accuracies = {}
for idx in range(np.max(age_groups) + 1):
    # Filter predictions and true labels for the current class
    mask = (true_classes == idx)
    accuracy = accuracy_score(true_classes[mask], predicted_classes[mask])
    class_accuracies[age_group_to_interval(idx)] = accuracy
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# Print accuracy for each class
for age_range, accuracy in class_accuracies.items():
    print(f'Accuracy for age range {age_range}: {accuracy:.2f}')
# Out:
# Accuracy for age range 0-4: 0.92
# Accuracy for age range 5-9: 0.42
# Accuracy for age range 10-14: 0.46
# Accuracy for age range 15-19: 0.11
# Accuracy for age range 20-24: 0.33
# Accuracy for age range 25-29: 0.14
# Accuracy for age range 30-34: 0.00
# Accuracy for age range 35-39: 0.00
# Accuracy for age range 40-44: 0.00
# Accuracy for age range 45-49: 0.00
# Accuracy for age range 50-54: 0.00
# Accuracy for age range 55-59: 0.00
# Accuracy for age range 60-64: 0.00
# Accuracy for age range 65-69: 0.12
# Accuracy for age range 70-74: 0.00
# Accuracy for age range 75-79: 0.00
# Accuracy for age range 80-84: 0.00
# Accuracy for age range 85-89: 0.00
# Accuracy for age range 90-94: 0.00
# Accuracy for age range 95-99: nan
# Accuracy for age range 100-104: nan
# Accuracy for age range 105-109: nan
# Accuracy for age range 110-114: 0.00
# Accuracy for age range 115-119: 0.00

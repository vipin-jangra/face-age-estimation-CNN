# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin-jangra/face-age-estimation-CNN/blob/main/D1_CNN2_A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import keras
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.applications import ResNet101
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img, img_to_array
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from keras.applications.resnet50 import preprocess_input

# %%
def preprocess_image(image_path):
    # Read grayscale image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    # Resize image to (224, 224)
    image = cv2.resize(image, (224, 224))
    # Convert grayscale to RGB by stacking the single channel
    image_rgb = np.stack((image,) * 3, axis=-1)
    # Preprocess image for ResNet50 model
    image_rgb = preprocess_input(image_rgb)
    return image_rgb

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define age ranges
age_ranges = [(1, 2), (3, 9), (10, 20), (21, 27), (28, 45), (46, 65), (66, 116)]

# Function to map age to range index
def age_to_range(age, age_ranges):
    for idx, (start, end) in enumerate(age_ranges):
        if start <= age <= end:
            return idx
    return None

# %%
def preprocess_labels(labels, num_classes):
    # One-hot encode labels
    labels = to_categorical(labels, num_classes=num_classes)
    return labels

# %%
# Load and preprocess the dataset
image_dir = '/content/drive/MyDrive/Dataset/part1'
images=[]
image_paths = []
age_labels = []
age_groups = []
target_size = (224, 224)

for i,filename in enumerate(os.listdir(image_dir)):
  if i>=100:
    break
  if filename.endswith(".jpg"):
    age = int(filename.split('_')[0])
    range_index = age_to_range(age, age_ranges)
    age_labels.append(range_index)

    image_path = os.path.join(image_dir, filename)
    image = preprocess_image(image_path)
    images.append(image)
    image_paths.append(image_path)

images = np.array(images)
age_groups = age_labels
age_labels = preprocess_labels(age_labels, len(age_ranges))

# %%
print(f'number of images : {len(images)}')
# Out:
# number of images : 100

# %%
# Function to convert age group index to interval string
def age_group_to_interval(group_index):
    start = group_index * 5
    end = (group_index + 1) * 5
    return f"{start}-{end}"

# %%
import pandas as pd
df = pd.DataFrame()
age_intervals = [age_to_range(age,age_ranges) for age in age_groups]
df['images_path'],df['age'] = image_paths,age_intervals
df.head(10)
# Out:
#                                          images_path  age
# 0  /content/drive/MyDrive/Dataset/part1/28_1_0_20...    1
# 1  /content/drive/MyDrive/Dataset/part1/35_0_0_20...    1
# 2  /content/drive/MyDrive/Dataset/part1/38_0_4_20...    1
# 3  /content/drive/MyDrive/Dataset/part1/50_1_0_20...    1
# 4  /content/drive/MyDrive/Dataset/part1/20_1_2_20...    0
# 5  /content/drive/MyDrive/Dataset/part1/35_0_4_20...    1
# 6  /content/drive/MyDrive/Dataset/part1/57_0_0_20...    1
# 7  /content/drive/MyDrive/Dataset/part1/51_0_0_20...    1
# 8  /content/drive/MyDrive/Dataset/part1/36_1_0_20...    1
# 9  /content/drive/MyDrive/Dataset/part1/39_0_0_20...    1

# %%
plt.figure(figsize=(20,20))
samples = df.iloc[0:16]

for index,sample,age in samples.itertuples():
  plt.subplot(4,4,index+1)
  img = load_img(sample)
  img = np.array(img)
  plt.axis('off')
  plt.title(f'Age:{age}')
  plt.imshow(img)

# %%
#age distribution
sns.displot(data=age_labels,kde=True)

# %%
train_images, test_images, train_age_groups, test_age_groups = train_test_split(images, age_labels, test_size=0.2, random_state=42)

# %%
# Load ResNet101 with pre-trained ImageNet weights, excluding the top layers
base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step

# %%
# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(132, activation='relu')(x)
predictions = Dense(len(age_ranges), activation='softmax')(x)

# Create the complete model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(
    '/content/drive/MyDrive/Dataset/D1_CNN2_A3.h5',  # Filepath to save the best model
    monitor='val_accuracy',  # Metric to monitor
    verbose=1,
    save_best_only=True,  # Only save the best model
    mode='max'  # Mode to determine best (maximizing validation accuracy)
)

# %%
model.fit(train_images, train_age_groups, validation_split=0.2, epochs=60, batch_size=32, callbacks=[model_checkpoint], shuffle=False)
# Out:
# Epoch 1/60
# 2/2 [==============================] - ETA: 0s - loss: 1.7023 - accuracy: 0.4219
# Epoch 1: val_accuracy improved from -inf to 0.31250, saving model to /content/drive/MyDrive/Dataset/D1_CNN2_A3.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 76s 6s/step - loss: 1.7023 - accuracy: 0.4219 - val_loss: 5.4480 - val_accuracy: 0.3125
# Epoch 2/60
# 2/2 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.7656
# Epoch 2: val_accuracy improved from 0.31250 to 0.43750, saving model to /content/drive/MyDrive/Dataset/D1_CNN2_A3.h5
# 2/2 [==============================] - 3s 3s/step - loss: 0.6307 - accuracy: 0.7656 - val_loss: 222.4311 - val_accuracy: 0.4375
# Epoch 3/60
# 2/2 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9688
# Epoch 3: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.1633 - accuracy: 0.9688 - val_loss: 55.6261 - val_accuracy: 0.4375
# Epoch 4/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9844
# Epoch 4: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0883 - accuracy: 0.9844 - val_loss: 213.4107 - val_accuracy: 0.4375
# Epoch 5/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9688
# Epoch 5: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0643 - accuracy: 0.9688 - val_loss: 444.8690 - val_accuracy: 0.4375
# Epoch 6/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9688
# Epoch 6: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0876 - accuracy: 0.9688 - val_loss: 1193.4757 - val_accuracy: 0.3750
# Epoch 7/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9844
# Epoch 7: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0653 - accuracy: 0.9844 - val_loss: 11370.8496 - val_accuracy: 0.4375
# Epoch 8/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9844
# Epoch 8: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0337 - accuracy: 0.9844 - val_loss: 102689.8438 - val_accuracy: 0.4375
# Epoch 9/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9844
# Epoch 9: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 315ms/step - loss: 0.0631 - accuracy: 0.9844 - val_loss: 706861.2500 - val_accuracy: 0.4375
# Epoch 10/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9844
# Epoch 10: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0414 - accuracy: 0.9844 - val_loss: 4611740.0000 - val_accuracy: 0.4375
# Epoch 11/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 14632971.0000 - val_accuracy: 0.4375
# Epoch 12/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9844
# Epoch 12: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 307ms/step - loss: 0.0400 - accuracy: 0.9844 - val_loss: 31274704.0000 - val_accuracy: 0.4375
# Epoch 13/60
# 2/2 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.9062
# Epoch 13: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 0.4767 - accuracy: 0.9062 - val_loss: 63370256.0000 - val_accuracy: 0.4375
# Epoch 14/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9844
# Epoch 14: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 302ms/step - loss: 0.0931 - accuracy: 0.9844 - val_loss: 36301180.0000 - val_accuracy: 0.4375
# Epoch 15/60
# 2/2 [==============================] - ETA: 0s - loss: 0.3417 - accuracy: 0.9375
# Epoch 15: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 302ms/step - loss: 0.3417 - accuracy: 0.9375 - val_loss: 51033832.0000 - val_accuracy: 0.4375
# Epoch 16/60
# 2/2 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.9062
# Epoch 16: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 301ms/step - loss: 0.3594 - accuracy: 0.9062 - val_loss: 156149328.0000 - val_accuracy: 0.4375
# Epoch 17/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1417794048.0000 - val_accuracy: 0.4375
# Epoch 18/60
# 2/2 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9688
# Epoch 18: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.1040 - accuracy: 0.9688 - val_loss: 3765376000.0000 - val_accuracy: 0.4375
# Epoch 19/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9844
# Epoch 19: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0724 - accuracy: 0.9844 - val_loss: 4628180992.0000 - val_accuracy: 0.4375
# Epoch 20/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 4031979520.0000 - val_accuracy: 0.4375
# Epoch 21/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9844
# Epoch 21: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 307ms/step - loss: 0.0239 - accuracy: 0.9844 - val_loss: 3191249920.0000 - val_accuracy: 0.4375
# Epoch 22/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2004051968.0000 - val_accuracy: 0.4375
# Epoch 23/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9844
# Epoch 23: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0212 - accuracy: 0.9844 - val_loss: 1103989504.0000 - val_accuracy: 0.4375
# Epoch 24/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 558974208.0000 - val_accuracy: 0.4375
# Epoch 25/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 274426432.0000 - val_accuracy: 0.4375
# Epoch 26/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 134164000.0000 - val_accuracy: 0.4375
# Epoch 27/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 66695600.0000 - val_accuracy: 0.4375
# Epoch 28/60
# 2/2 [==============================] - ETA: 0s - loss: 9.0667e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 317ms/step - loss: 9.0667e-04 - accuracy: 1.0000 - val_loss: 34492104.0000 - val_accuracy: 0.4375
# Epoch 29/60
# 2/2 [==============================] - ETA: 0s - loss: 4.8372e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 4.8372e-04 - accuracy: 1.0000 - val_loss: 18274976.0000 - val_accuracy: 0.4375
# Epoch 30/60
# 2/2 [==============================] - ETA: 0s - loss: 5.0848e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 5.0848e-04 - accuracy: 1.0000 - val_loss: 9860334.0000 - val_accuracy: 0.4375
# Epoch 31/60
# 2/2 [==============================] - ETA: 0s - loss: 2.2674e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 2.2674e-04 - accuracy: 1.0000 - val_loss: 5437324.5000 - val_accuracy: 0.4375
# Epoch 32/60
# 2/2 [==============================] - ETA: 0s - loss: 1.6350e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 315ms/step - loss: 1.6350e-04 - accuracy: 1.0000 - val_loss: 3081664.0000 - val_accuracy: 0.4375
# Epoch 33/60
# 2/2 [==============================] - ETA: 0s - loss: 1.4022e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 1.4022e-04 - accuracy: 1.0000 - val_loss: 1799555.2500 - val_accuracy: 0.4375
# Epoch 34/60
# 2/2 [==============================] - ETA: 0s - loss: 1.2762e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 308ms/step - loss: 1.2762e-04 - accuracy: 1.0000 - val_loss: 1079229.8750 - val_accuracy: 0.4375
# Epoch 35/60
# 2/2 [==============================] - ETA: 0s - loss: 1.1261e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 1.1261e-04 - accuracy: 1.0000 - val_loss: 664442.8750 - val_accuracy: 0.4375
# Epoch 36/60
# 2/2 [==============================] - ETA: 0s - loss: 9.4828e-05 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 307ms/step - loss: 9.4828e-05 - accuracy: 1.0000 - val_loss: 418863.3750 - val_accuracy: 0.4375
# Epoch 37/60
# 2/2 [==============================] - ETA: 0s - loss: 7.8316e-05 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 7.8316e-05 - accuracy: 1.0000 - val_loss: 269883.2188 - val_accuracy: 0.4375
# Epoch 38/60
# 2/2 [==============================] - ETA: 0s - loss: 6.5102e-05 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 307ms/step - loss: 6.5102e-05 - accuracy: 1.0000 - val_loss: 177397.3750 - val_accuracy: 0.4375
# Epoch 39/60
# 2/2 [==============================] - ETA: 0s - loss: 5.5136e-05 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 303ms/step - loss: 5.5136e-05 - accuracy: 1.0000 - val_loss: 118887.2109 - val_accuracy: 0.4375
# Epoch 40/60
# 2/2 [==============================] - ETA: 0s - loss: 4.7768e-05 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 4.7768e-05 - accuracy: 1.0000 - val_loss: 81144.6406 - val_accuracy: 0.4375
# Epoch 41/60
# 2/2 [==============================] - ETA: 0s - loss: 4.2175e-05 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 4.2175e-05 - accuracy: 1.0000 - val_loss: 56461.2461 - val_accuracy: 0.3750
# Epoch 42/60
# 2/2 [==============================] - ETA: 0s - loss: 3.7663e-05 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 3.7663e-05 - accuracy: 1.0000 - val_loss: 40201.4297 - val_accuracy: 0.3750
# Epoch 43/60
# 2/2 [==============================] - ETA: 0s - loss: 3.4017e-05 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 3.4017e-05 - accuracy: 1.0000 - val_loss: 29057.7402 - val_accuracy: 0.3750
# Epoch 44/60
# 2/2 [==============================] - ETA: 0s - loss: 3.1044e-05 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 3.1044e-05 - accuracy: 1.0000 - val_loss: 21305.6797 - val_accuracy: 0.3750
# Epoch 45/60
# 2/2 [==============================] - ETA: 0s - loss: 2.8536e-05 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 309ms/step - loss: 2.8536e-05 - accuracy: 1.0000 - val_loss: 15844.4355 - val_accuracy: 0.3750
# Epoch 46/60
# 2/2 [==============================] - ETA: 0s - loss: 2.6379e-05 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 2.6379e-05 - accuracy: 1.0000 - val_loss: 11935.2109 - val_accuracy: 0.3750
# Epoch 47/60
# 2/2 [==============================] - ETA: 0s - loss: 2.4563e-05 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 2.4563e-05 - accuracy: 1.0000 - val_loss: 9107.0898 - val_accuracy: 0.3750
# Epoch 48/60
# 2/2 [==============================] - ETA: 0s - loss: 2.2975e-05 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 307ms/step - loss: 2.2975e-05 - accuracy: 1.0000 - val_loss: 7026.4761 - val_accuracy: 0.3750
# Epoch 49/60
# 2/2 [==============================] - ETA: 0s - loss: 2.1611e-05 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 2.1611e-05 - accuracy: 1.0000 - val_loss: 5477.4531 - val_accuracy: 0.3750
# Epoch 50/60
# 2/2 [==============================] - ETA: 0s - loss: 2.0403e-05 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 2.0403e-05 - accuracy: 1.0000 - val_loss: 4311.6157 - val_accuracy: 0.3750
# Epoch 51/60
# 2/2 [==============================] - ETA: 0s - loss: 1.9365e-05 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 1.9365e-05 - accuracy: 1.0000 - val_loss: 3422.6924 - val_accuracy: 0.3750
# Epoch 52/60
# 2/2 [==============================] - ETA: 0s - loss: 1.8419e-05 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 304ms/step - loss: 1.8419e-05 - accuracy: 1.0000 - val_loss: 2741.1074 - val_accuracy: 0.3750
# Epoch 53/60
# 2/2 [==============================] - ETA: 0s - loss: 1.7586e-05 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 309ms/step - loss: 1.7586e-05 - accuracy: 1.0000 - val_loss: 2213.8601 - val_accuracy: 0.3750
# Epoch 54/60
# 2/2 [==============================] - ETA: 0s - loss: 1.6862e-05 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 1.6862e-05 - accuracy: 1.0000 - val_loss: 1802.6598 - val_accuracy: 0.3750
# Epoch 55/60
# 2/2 [==============================] - ETA: 0s - loss: 1.6195e-05 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 1.6195e-05 - accuracy: 1.0000 - val_loss: 1479.8668 - val_accuracy: 0.3750
# Epoch 56/60
# 2/2 [==============================] - ETA: 0s - loss: 1.5601e-05 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 308ms/step - loss: 1.5601e-05 - accuracy: 1.0000 - val_loss: 1223.1436 - val_accuracy: 0.3750
# Epoch 57/60
# 2/2 [==============================] - ETA: 0s - loss: 1.5072e-05 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 309ms/step - loss: 1.5072e-05 - accuracy: 1.0000 - val_loss: 1017.9751 - val_accuracy: 0.3750
# Epoch 58/60
# 2/2 [==============================] - ETA: 0s - loss: 1.4584e-05 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 1.4584e-05 - accuracy: 1.0000 - val_loss: 856.8359 - val_accuracy: 0.3125
# Epoch 59/60
# 2/2 [==============================] - ETA: 0s - loss: 1.4128e-05 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 305ms/step - loss: 1.4128e-05 - accuracy: 1.0000 - val_loss: 726.7031 - val_accuracy: 0.3125
# Epoch 60/60
# 2/2 [==============================] - ETA: 0s - loss: 1.3725e-05 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.43750
# 2/2 [==============================] - 1s 306ms/step - loss: 1.3725e-05 - accuracy: 1.0000 - val_loss: 619.7981 - val_accuracy: 0.2500

# %%
# Load the best model
model.load_weights('/content/drive/MyDrive/Dataset/D1_CNN2_A3.h5')

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_age_groups)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 1/1 [==============================] - 1s 919ms/step - loss: 145.0089 - accuracy: 0.4500
# Test Accuracy: 45.00%

# %%
predictions = model.predict(test_images)

# Convert predictions to class labels if needed
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_age_groups, axis=1)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# Example metrics calculation
from sklearn.metrics import classification_report

print(classification_report(true_classes, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         3
#            4       0.45      1.00      0.62         9
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.45        20
#    macro avg       0.09      0.20      0.12        20
# weighted avg       0.20      0.45      0.28        20
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculate classification metrics
accuracy = accuracy_score(true_classes, predicted_classes)
precision = precision_score(true_classes, predicted_classes, average='weighted')
recall = recall_score(true_classes, predicted_classes, average='weighted')
f1 = f1_score(true_classes, predicted_classes, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Accuracy: 0.45
# Precision: 0.20
# Recall: 0.45
# F1-score: 0.28
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculate accuracy for each class
class_accuracies = {}
for idx, (start, end) in enumerate(age_ranges):
    # Filter predictions and true labels for the current class
    mask = (true_classes == idx)
    accuracy = accuracy_score(true_classes[mask], predicted_classes[mask])
    class_accuracies[f'{start}-{end}'] = accuracy
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
